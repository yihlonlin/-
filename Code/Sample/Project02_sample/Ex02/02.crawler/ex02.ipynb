# %%
# 安裝
#! pip install pandas

# %%
import pandas as pd
url = "http://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=1216&SYEAR=2017&SSEASON=1&REPORT_ID=C"  ## 公開資訊觀測站的財報
dfs = pd.read_html(url)  ## 回傳DataFrame類別的陣列
df = dfs[1]
print(df)
# Out:
#                                0            1            2            3
# 0                           會計項目  2017年03月31日  2016年12月31日  2016年03月31日
# 1                          資產負債表          NaN          NaN          NaN
# 2                             資產          NaN          NaN          NaN
# 3                           流動資產          NaN          NaN          NaN
# 4                        現金及約當現金          NaN          NaN          NaN
# 5                      現金及約當現金合計     46462223     56334630     45417491
# 6            透過損益按公允價值衡量之金融資產－流動          NaN          NaN          NaN
# 7          透過損益按公允價值衡量之金融資產－流動合計      6415371      6033382      9692821
# 8                         應收票據淨額          NaN          NaN          NaN
# 9                         應收票據淨額      1345718      1529140      1432106
# 10                    應收票據－關係人淨額          NaN          NaN          NaN
# 11                    應收票據－關係人淨額          539         1623         1978
# 12                        應收帳款淨額          NaN          NaN          NaN
# 13                        應收帳款淨額     12809550     13422659     14204568
# 14                    應收帳款－關係人淨額          NaN          NaN          NaN
# 15                    應收帳款－關係人淨額      1223726      1923453      1847335
# 16                         其他應收款          NaN          NaN          NaN
# 17                       其他應收款淨額      6437746      7125917      3137922
# 18                       當期所得稅資產          NaN          NaN          NaN
# 19                     本期所得稅資產合計       191746       236496       121439
# 20                            存貨          NaN          NaN          NaN
# 21                          存貨合計     30532934     30616333     29968141
# 22                          預付款項          NaN          NaN          NaN
# 23                        預付款項合計      3795906      4271619     13337843
# 24             待出售非流動資產(或處分群組)淨額          NaN          NaN          NaN
# 25             待出售非流動資產(或處分群組)淨額            0      7854383            0
# 26                        其他流動資產          NaN          NaN          NaN
# 27                      其他流動資產合計     12447034     10469366     18298325
# 28                        流動資產合計    121662493    139819001    137459969
# 29                         非流動資產          NaN          NaN          NaN
# ..                           ...          ...          ...          ...
# 98                   歸屬於母公司業主之權益          NaN          NaN          NaN
# 99                            股本          NaN          NaN          NaN
# 100                        普通股股本     56820154     56820154     56820154
# 101                         股本合計     56820154     56820154     56820154
# 102                         資本公積          NaN          NaN          NaN
# 103                    資本公積－發行溢價          NaN          NaN          NaN
# 104                  資本公積－發行溢價合計       438468       438468       438468
# 105   資本公積－實際取得或處分子公司股權價格與帳面價值差額      3040044      3039918      3140390
# 106  資本公積－採用權益法認列關聯企業及合資股權淨值之變動數       278130       278130       280271
# 107                      資本公積－其他       145067       143622       140066
# 108                       資本公積合計      3901709      3900138      3999195
# 109                         保留盈餘          NaN          NaN          NaN
# 110                       法定盈餘公積     15136198     15136198     13725414
# 111                       特別盈餘公積      4042765      4042765      4043384
# 112                未分配盈餘（或待彌補虧損）          NaN          NaN          NaN
# 113              未分配盈餘（或待彌補虧損）合計     20798380     16329791     19452932
# 114                       保留盈餘合計     39977343     35508754     37221730
# 115                         其他權益          NaN          NaN          NaN
# 116            國外營運機構財務報表換算之兌換差額          NaN          NaN          NaN
# 117          國外營運機構財務報表換算之兌換差額合計     -5494846     -2257350      1594390
# 118                備供出售金融資產未實現損益          NaN          NaN          NaN
# 119              備供出售金融資產未實現損益合計       489902       434151       622906
# 120                       其他權益合計     -5004944     -1823199      2217296
# 121                歸屬於母公司業主之權益合計     95694262     94405847    100258375
# 122                        非控制權益     58962565     58294419     61203820
# 123                         權益總計    154656827    152700266    161462195
# 124                      負債及權益總計    353964073    378585465    396467101
# 125                      待註銷股本股數            0            0            0
# 126            預收股款（權益項下）之約當發行股數            0            0            0
# 127    母公司暨子公司所持有之母公司庫藏股股數（單位：股）            0            0            0
#
# [128 rows x 4 columns]

# %%
# 簡單的操作pandas教學
## 只查看前面五行
print(df.head(5))

## 查看所有的columns
columns = df.columns
print(columns)

## 僅查看取特定column
showColumns = [columns[0], columns[1]]
print(df[showColumns].head())

## 僅查看特定的row
print(df.xs(5))  ##不可指派內容
print(df.loc[5])  ##可指派內容

## 存檔
df.to_csv("test.csv", index=False)
df.to_json(orient='records')
# Out:
#          0            1            2            3
# 0     會計項目  2017年03月31日  2016年12月31日  2016年03月31日
# 1    資產負債表          NaN          NaN          NaN
# 2       資產          NaN          NaN          NaN
# 3     流動資產          NaN          NaN          NaN
# 4  現金及約當現金          NaN          NaN          NaN
# Int64Index([0, 1, 2, 3], dtype='int64')
#          0            1
# 0     會計項目  2017年03月31日
# 1    資產負債表          NaN
# 2       資產          NaN
# 3     流動資產          NaN
# 4  現金及約當現金          NaN
# 0    現金及約當現金合計
# 1     46462223
# 2     56334630
# 3     45417491
# Name: 5, dtype: object
# 0    現金及約當現金合計
# 1     46462223
# 2     56334630
# 3     45417491
# Name: 5, dtype: object
# '[{"0":"\\u6703\\u8a08\\u9805\\u76ee","1":"2017\\u5e7403\\u670831\\u65e5","2":"2016\\u5e7412\\u670831\\u65e5","3":"2016\\u5e7403\\u670831\\u65e5"},{"0":"\\u8cc7\\u7522\\u8ca0\\u50b5\\u8868","1":null,"2":null,"3":null},{"0":"\\u8cc7\\u7522","1":null,"2":null,"3":null},{"0":"\\u6d41\\u52d5\\u8cc7\\u7522","1":null,"2":null,"3":null},{"0":"\\u73fe\\u91d1\\u53ca\\u7d04\\u7576\\u73fe\\u91d1","1":null,"2":null,"3":null},{"0":"\\u73fe\\u91d1\\u53ca\\u7d04\\u7576\\u73fe\\u91d1\\u5408\\u8a08","1":"46462223","2":"56334630","3":"45417491"},{"0":"\\u900f\\u904e\\u640d\\u76ca\\u6309\\u516c\\u5141\\u50f9\\u503c\\u8861\\u91cf\\u4e4b\\u91d1\\u878d\\u8cc7\\u7522\\uff0d\\u6d41\\u52d5","1":null,"2":null,"3":null},{"0":"\\u900f\\u904e\\u640d\\u76ca\\u6309\\u516c\\u5141\\u50f9\\u503c\\u8861\\u91cf\\u4e4b\\u91d1\\u878d\\u8cc7\\u7522\\uff0d\\u6d41\\u52d5\\u5408\\u8a08","1":"6415371","2":"6033382","3":"9692821"},{"0":"\\u61c9\\u6536\\u7968\\u64da\\u6de8\\u984d","1":null,"2":null,"3":null},{"0":"\\u61c9\\u6536\\u7968\\u64da\\u6de8\\u984d","1":"1345718","2":"1529140","3":"1432106"},{"0":"\\u61c9\\u6536\\u7968\\u64da\\uff0d\\u95dc\\u4fc2\\u4eba\\u6de8\\u984d","1":null,"2":null,"3":null},{"0":"\\u61c9\\u6536\\u7968\\u64da\\uff0d\\u95dc\\u4fc2\\u4eba\\u6de8\\u984d","1":"539","2":"1623","3":"1978"},{"0":"\\u61c9\\u6536\\u5e33\\u6b3e\\u6de8\\u984d","1":null,"2":null,"3":null},{"0":"\\u61c9\\u6536\\u5e33\\u6b3e\\u6de8\\u984d","1":"12809550","2":"13422659","3":"14204568"},{"0":"\\u61c9\\u6536\\u5e33\\u6b3e\\uff0d\\u95dc\\u4fc2\\u4eba\\u